# %% [markdown]
# # 🔄 Basic Agent Workflows with GitHub Models (Python)
#
# ## 📋 Workflow Orchestration Tutorial
#
# This notebook introduces the powerful **Workflow Builder** capabilities of the Microsoft Agent Framework. Learn how to create sophisticated, multi-step agent workflows that can handle complex business processes and coordinate multiple AI operations seamlessly.
#
# ## 🎯 Learning Objectives
#
# ### 🏗️ **Workflow Architecture**
# - **Workflow Builder**: Design and orchestrate complex multi-step processes
# - **Event-Driven Execution**: Handle workflow events and state transitions
# - **Visual Workflow Design**: Create and visualize workflow structures
# - **GitHub Models Integration**: Leverage AI models within workflow contexts
#
# ### 🔄 **Process Orchestration**
# - **Sequential Operations**: Chain multiple agent tasks in logical order
# - **Conditional Logic**: Implement decision points and branching workflows
# - **Error Handling**: Robust error recovery and workflow resilience
# - **State Management**: Track and manage workflow execution state
#
# ### 📊 **Enterprise Workflow Patterns**
# - **Business Process Automation**: Automate complex organizational workflows
# - **Multi-Agent Coordination**: Coordinate multiple specialized agents
# - **Scalable Execution**: Design workflows for enterprise-scale operations
# - **Monitoring & Observability**: Track workflow performance and outcomes
#
# ## ⚙️ Prerequisites & Setup
#
# ### 📦 **Required Dependencies**
#
# Install the Agent Framework with workflow capabilities:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **GitHub Models Configuration**
#
# **Environment Setup (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ### 🏢 **Enterprise Use Cases**
#
# **Business Process Examples:**
# - **Customer Onboarding**: Multi-step verification and setup workflows
# - **Content Pipeline**: Automated content creation, review, and publishing
# - **Data Processing**: ETL workflows with AI-powered transformation
# - **Quality Assurance**: Automated testing and validation processes
#
# **Workflow Benefits:**
# - 🎯 **Reliability**: Deterministic execution with error recovery
# - 📈 **Scalability**: Handle high-volume process automation
# - 🔍 **Observability**: Complete audit trails and monitoring
# - 🔧 **Maintainability**: Visual design and modular components
#
# ## 🎨 Workflow Design Patterns
#
# ### Basic Workflow Structure
# ```mermaid
# graph TD
#     A[Start] --> B[Agent Task 1]
#     B --> C{Decision Point}
#     C -->|Success| D[Agent Task 2]
#     C -->|Failure| E[Error Handler]
#     D --> F[End]
#     E --> F
# ```
#
# **Key Components:**
# - **WorkflowBuilder**: Main orchestration engine
# - **WorkflowEvent**: Event handling and communication
# - **WorkflowViz**: Visual workflow representation and debugging
#
# Let's build your first intelligent workflow! 🚀

# %%
! pip install agent-framework-core -U
# Out:
# Requirement already satisfied: agent-framework-core in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (1.0.0b260212)
# Requirement already satisfied: typing-extensions in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from agent-framework-core) (4.15.0)
# Requirement already satisfied: pydantic<3,>=2 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from agent-framework-core) (2.11.10)
# Requirement already satisfied: python-dotenv<2,>=1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from agent-framework-core) (1.2.1)
# Requirement already satisfied: opentelemetry-api>=1.39.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from agent-framework-core) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.39.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from agent-framework-core) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from agent-framework-core) (0.4.13)
# Requirement already satisfied: openai>=1.99.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from agent-framework-core) (2.20.0)
# Requirement already satisfied: azure-identity<2,>=1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from agent-framework-core) (1.25.2)
# Requirement already satisfied: azure-ai-projects>=2.0.0b3 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from agent-framework-core) (2.0.0b3)
# Requirement already satisfied: mcp<2,>=1.24.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp[ws]<2,>=1.24.0->agent-framework-core) (1.26.0)
# Requirement already satisfied: packaging>=24.1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from agent-framework-core) (26.0)
# Requirement already satisfied: azure-core>=1.31.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.38.1)
# Requirement already satisfied: cryptography>=2.5 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from azure-identity<2,>=1->agent-framework-core) (46.0.5)
# Requirement already satisfied: msal>=1.31.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.3.1)
# Requirement already satisfied: anyio>=4.5 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (4.12.1)
# Requirement already satisfied: httpx-sse>=0.4 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (4.26.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.0.22)
# Requirement already satisfied: sse-starlette>=1.6.1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (3.2.0)
# Requirement already satisfied: starlette>=0.27 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.40.0)
# Requirement already satisfied: websockets>=15.0.1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp[ws]<2,>=1.24.0->agent-framework-core) (15.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from pydantic<3,>=2->agent-framework-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from pydantic<3,>=2->agent-framework-core) (2.33.2)
# Requirement already satisfied: idna>=2.8 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from anyio>=4.5->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (3.11)
# Requirement already satisfied: isodate>=0.6.1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from azure-ai-projects>=2.0.0b3->agent-framework-core) (0.7.2)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from azure-ai-projects>=2.0.0b3->agent-framework-core) (12.28.0)
# Requirement already satisfied: requests>=2.21.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.0.0)
# Requirement already satisfied: pycparser in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (3.0)
# Requirement already satisfied: certifi in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.36.2)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.30.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.6.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from openai>=1.99.0->agent-framework-core) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from openai>=1.99.0->agent-framework-core) (0.13.0)
# Requirement already satisfied: sniffio in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from openai>=1.99.0->agent-framework-core) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from openai>=1.99.0->agent-framework-core) (4.67.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from opentelemetry-api>=1.39.0->agent-framework-core) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.39.0->agent-framework-core) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from opentelemetry-sdk>=1.39.0->agent-framework-core) (0.60b1)
# Requirement already satisfied: click>=7.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from uvicorn>=0.31.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (8.3.1)

# %%
# 🔄 Import Workflow and Agent Framework Components
# Core components for building sophisticated agent workflows

from agent_framework.openai import OpenAIChatClient    # 🤖 GitHub Models client integration
from agent_framework import WorkflowBuilder, WorkflowEvent, WorkflowViz  # 🏗️ Workflow orchestration tools

# %%
# 📦 Import Environment and System Utilities
# Essential libraries for configuration and environment management

import os                      # 🔧 Environment variable access
from dotenv import load_dotenv # 📁 Secure configuration loading

# %%
# 🔧 Initialize Environment Configuration
# Load GitHub Models API credentials from .env file
load_dotenv()
# Out:
# True

# %%
# 🔗 Initialize GitHub Models Chat Client for Workflow Operations
# Create the AI client that will power agents within our workflow
chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # 🌐 GitHub Models API endpoint
    api_key=os.environ.get("GITHUB_TOKEN"),        # 🔑 Authentication token
    model_id=os.environ.get("GITHUB_MODEL_ID")  # 🎯 Selected AI model
)

# %%
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an are hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. 
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
reviewer_agent   = chat_client.as_agent(
        instructions=(
           REVIEWER_INSTRUCTIONS
        ),
        name=REVIEWER_NAME,
    )

front_desk_agent = chat_client.as_agent(
        instructions=(
            FRONTDESK_INSTRUCTIONS
        ),
        name=FRONTDESK_NAME,
    )

# %%
workflow = WorkflowBuilder(start_executor=front_desk_agent).add_edge(front_desk_agent, reviewer_agent).build()

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
svg_file = viz.export(format="svg")
print(f"SVG file saved to: {svg_file}")
# Out:
# Generating workflow visualization...
# Mermaid string:
# =======
# flowchart TD
#   FrontDesk["FrontDesk (Start)"];
#   Concierge["Concierge"];
#   FrontDesk --> Concierge;
# =======
# DiGraph string:
# =======
# digraph Workflow {
#   rankdir=TD;
#   node [shape=box, style=filled, fillcolor=lightblue];
#   edge [color=black, arrowhead=vee];
#
#   "FrontDesk" [fillcolor=lightgreen, label="FrontDesk\n(Start)"];
#   "Concierge" [label="Concierge"];
#   "FrontDesk" -> "Concierge";
# }
# =======
# SVG file saved to: /tmp/tmpn3kov6tg.svg

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
# Display the exported workflow SVG inline in the notebook

from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")
# Out:
# Attempting to display SVG file at: /tmp/tmpn3kov6tg.svg

# %%
result =''
result = await workflow.run("I would like to go to Paris.")
# async for event in workflow.run('I would like to go to Paris.', stream=True):
#     if isinstance(event, DatabaseEvent):
#         print(f"{event}")
#     if isinstance(event, WorkflowEvent):
#         result += str(event.data)
#         # print(f"Workflow output: {event.data}")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# File ~/.pyenv/versions/venv/lib/python3.13/site-packages/agent_framework/openai/_chat_client.py:254, in RawOpenAIChatClient._inner_get_response.<locals>._get_response()
#     252 try:
#     253     return self._parse_response_from_openai(
# --> 254         await client.chat.completions.create(stream=False, **options_dict), options
#     255     )
#     256 except BadRequestError as ex:
#
# File ~/.pyenv/versions/venv/lib/python3.13/site-packages/openai/resources/chat/completions/completions.py:2678, in AsyncCompletions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    2677 validate_response_format(response_format)
# -> 2678 return await self._post(
#    2679     "/chat/completions",
#    2680     body=await async_maybe_transform(
#    2681         {
#    2682             "messages": messages,
#    2683             "model": model,
#    2684             "audio": audio,
#    2685             "frequency_penalty": frequency_penalty,
#    2686             "function_call": function_call,
#    2687             "functions": functions,
#    2688             "logit_bias": logit_bias,
#    2689             "logprobs": logprobs,
#    2690             "max_completion_tokens": max_completion_tokens,
#    2691             "max_tokens": max_tokens,
#    2692             "metadata": metadata,
#    2693             "modalities": modalities,
#    2694             "n": n,
#    2695             "parallel_tool_calls": parallel_tool_calls,
#    2696             "prediction": prediction,
#    2697             "presence_penalty": presence_penalty,
#    2698             "prompt_cache_key": prompt_cache_key,
#    2699             "prompt_cache_retention": prompt_cache_retention,
#    2700             "reasoning_effort": reasoning_effort,
#    2701             "response_format": response_format,
#    2702             "safety_identifier": safety_identifier,
#    2703             "seed": seed,
#    2704             "service_tier": service_tier,
#    2705             "stop": stop,
#    2706             "store": store,
#    2707             "stream": stream,
#    2708             "stream_options": stream_options,
#    2709             "temperature": temperature,
#    2710             "tool_choice": tool_choice,
#    2711             "tools": tools,
#    2712             "top_logprobs": top_logprobs,
#    2713             "top_p": top_p,
#    2714             "user": user,
#    2715             "verbosity": verbosity,
#    2716             "web_search_options": web_search_options,
#    2717         },
#    2718         completion_create_params.CompletionCreateParamsStreaming
#    2719         if stream
#    2720         else completion_create_params.CompletionCreateParamsNonStreaming,
#    2721     ),
#    2722     options=make_request_options(
#    2723         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    2724     ),
#    2725     cast_to=ChatCompletion,
#    2726     stream=stream or False,
#    2727     stream_cls=AsyncStream[ChatCompletionChunk],
#    2728 )
#
# File ~/.pyenv/versions/venv/lib/python3.13/site-packages/openai/_base_client.py:1884, in AsyncAPIClient.post(self, path, cast_to, body, content, files, options, stream, stream_cls)
#    1881 opts = FinalRequestOptions.construct(
#    1882     method="post", url=path, json_data=body, content=content, files=await async_to_httpx_files(files), **options
#    1883 )
# -> 1884 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/.pyenv/versions/venv/lib/python3.13/site-packages/openai/_base_client.py:1669, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1668     log.debug("Re-raising status error")
# -> 1669     raise self._make_status_error_from_response(err.response) from None
#    1671 break
#
# RateLimitError: Too many requests. For more on scraping GitHub and how it may affect your rights, please review our Terms of Service (https://docs.github.com/en/site-policy/github-terms/github-terms-of-service).
#
# The above exception was the direct cause of the following exception:
#
# ServiceResponseException                  Traceback (most recent call last)
# Cell In[187], line 2
#       1 result =''
# ----> 2 result = await workflow.run("I would like to go to Paris.")
#       3 # async for event in workflow.run('I would like to go to Paris.', stream=True):
#       4 #     if isinstance(event, DatabaseEvent):
#       5 #         print(f"{event}")
#       6 #     if isinstance(event, WorkflowEvent):
#       7 #         result += str(event.data)
#       8 #         # print(f"Workflow output: {event.data}")
#
# File ~/.pyenv/versions/venv/lib/python3.13/site-packages/agent_framework/_types.py:2818, in ResponseStream.get_final_response(self)
#    2816 if not self._finalized:
#    2817     if not self._consumed:
# -> 2818         async for _ in self:
#    2819             pass
#    2820     # Use finalizer if configured, otherwise return collected updates
#
# File ~/.pyenv/versions/venv/lib/python3.13/site-packages/agent_framework/_types.py:2718, in ResponseStream.__anext__(self)
#    2716     self._iterator = stream.__aiter__()
#    2717 try:
# -> 2718     update = await self._iterator.__anext__()
#    2719 except StopAsyncIteration:
#    2720     self._consumed = True
#
# File ~/.pyenv/versions/venv/lib/python3.13/site-packages/agent_framework/_workflows/_workflow.py:563, in Workflow._run_core(self, message, responses, checkpoint_id, checkpoint_storage, streaming, **kwargs)
#     557     self._runner.context.set_runtime_checkpoint_storage(checkpoint_storage)
#     559 initial_executor_fn, reset_context = self._resolve_execution_mode(
#     560     message, responses, checkpoint_id, checkpoint_storage
#     561 )
# --> 563 async for event in self._run_workflow_with_tracing(
#     564     initial_executor_fn=initial_executor_fn,
#     565     reset_context=reset_context,
#     566     streaming=streaming,
#     567     run_kwargs=kwargs if kwargs else None,
#     568 ):
#     569     if event.type == "output" and not self._should_yield_output_event(event):
#     570         continue
#
# File ~/.pyenv/versions/venv/lib/python3.13/site-packages/agent_framework/_workflows/_workflow.py:358, in Workflow._run_workflow_with_tracing(self, initial_executor_fn, reset_context, streaming, run_kwargs)
#     356 # Execute initial setup if provided
#     357 if initial_executor_fn:
# --> 358     await initial_executor_fn()
#     360 # All executor executions happen within workflow span
#     361 async for event in self._runner.run_until_convergence():
#     362     # Track request events for final status determination
#
# File ~/.pyenv/versions/venv/lib/python3.13/site-packages/agent_framework/_workflows/_workflow.py:442, in Workflow._execute_with_message_or_checkpoint(self, message, checkpoint_id, checkpoint_storage)
#     440 elif message is not None:
#     441     executor = self.get_start_executor()
# --> 442     await executor.execute(
#     443         message,
#     444         [self.__class__.__name__],
#     445         self._state,
#     446         self._runner.context,
#     447         trace_contexts=None,
#     448         source_span_ids=None,
#     449     )
#
# File ~/.pyenv/versions/venv/lib/python3.13/site-packages/agent_framework/_workflows/_executor.py:278, in Executor.execute(self, message, source_executor_ids, state, runner_context, trace_contexts, source_span_ids)
#     276 await context.add_event(invoke_event)
#     277 try:
# --> 278     await handler(message, context)
#     279 except Exception as exc:
#     280     # Surface structured executor failure before propagating
#     281     with _framework_event_origin():
#
# File ~/.pyenv/versions/venv/lib/python3.13/site-packages/agent_framework/_workflows/_executor.py:663, in handler.<locals>.decorator.<locals>.wrapper(self, message, ctx)
#     660 @functools.wraps(func)
#     661 async def wrapper(self: ExecutorT, message: Any, ctx: ContextT) -> Any:
#     662     """Wrapper function to call the handler."""
# --> 663     return await func(self, message, ctx)
#
# File ~/.pyenv/versions/venv/lib/python3.13/site-packages/agent_framework/_workflows/_agent_executor.py:154, in AgentExecutor.from_str(self, text, ctx)
#     152 """Accept a raw user prompt string and run the agent (one-shot)."""
#     153 self._cache = normalize_messages_input(text)
# --> 154 await self._run_agent_and_emit(ctx)
#
# File ~/.pyenv/versions/venv/lib/python3.13/site-packages/agent_framework/_workflows/_agent_executor.py:304, in AgentExecutor._run_agent_and_emit(self, ctx)
#     301     response = await self._run_agent_streaming(cast(WorkflowContext[Never, AgentResponseUpdate], ctx))
#     302 else:
#     303     # Non-streaming mode: use run() and emit single event
# --> 304     response = await self._run_agent(cast(WorkflowContext[Never, AgentResponse], ctx))
#     306 # Snapshot current conversation as cache + latest agent outputs.
#     307 # Do not append to prior snapshots: callers may provide full-history messages
#     308 # in request.messages, and extending would duplicate prior turns.
#     309 self._full_conversation = list(self._cache) + (list(response.messages) if response else [])
#
# File ~/.pyenv/versions/venv/lib/python3.13/site-packages/agent_framework/_workflows/_agent_executor.py:331, in AgentExecutor._run_agent(self, ctx)
#     321 """Execute the underlying agent in non-streaming mode.
#     322
#     323 Args:
#    (...)    327     The complete AgentResponse, or None if waiting for user input.
#     328 """
#     329 run_kwargs, options = self._prepare_agent_run_args(ctx.get_state(WORKFLOW_RUN_KWARGS_KEY, {}))
# --> 331 response = await self._agent.run(
#     332     self._cache,
#     333     stream=False,
#     334     session=self._session,
#     335     options=options,
#     336     **run_kwargs,
#     337 )
#     338 await ctx.yield_output(response)
#     340 # Handle any user input requests
#
# File ~/.pyenv/versions/venv/lib/python3.13/site-packages/agent_framework/_agents.py:868, in RawAgent.run.<locals>._run_non_streaming()
#     860 async def _run_non_streaming() -> AgentResponse[Any]:
#     861     ctx = await self._prepare_run_context(
#     862         messages=messages,
#     863         session=session,
#    (...)    866         kwargs=kwargs,
#     867     )
# --> 868     response = await self.client.get_response(  # type: ignore[call-overload]
#     869         messages=ctx["session_messages"],
#     870         stream=False,
#     871         options=ctx["chat_options"],
#     872         **ctx["filtered_kwargs"],
#     873     )
#     875     if not response:
#     876         raise AgentExecutionException("Chat client did not return a response.")
#
# File ~/.pyenv/versions/venv/lib/python3.13/site-packages/agent_framework/_tools.py:1937, in FunctionInvocationLayer.get_response.<locals>._get_response()
#    1934     break
#    1935 errors_in_a_row = approval_result["errors_in_a_row"]
# -> 1937 response = await super_get_response(
#    1938     messages=prepped_messages,
#    1939     stream=False,
#    1940     options=mutable_options,
#    1941     **filtered_kwargs,
#    1942 )
#    1944 if response.conversation_id is not None:
#    1945     _update_conversation_id(kwargs, response.conversation_id, mutable_options)
#
# File ~/.pyenv/versions/venv/lib/python3.13/site-packages/agent_framework/openai/_chat_client.py:267, in RawOpenAIChatClient._inner_get_response.<locals>._get_response()
#     262     raise ServiceResponseException(
#     263         f"{type(self)} service failed to complete the prompt: {ex}",
#     264         inner_exception=ex,
#     265     ) from ex
#     266 except Exception as ex:
# --> 267     raise ServiceResponseException(
#     268         f"{type(self)} service failed to complete the prompt: {ex}",
#     269         inner_exception=ex,
#     270     ) from ex
#
# ServiceResponseException: <class 'agent_framework.openai._chat_client.OpenAIChatClient'> service failed to complete the prompt: Too many requests. For more on scraping GitHub and how it may affect your rights, please review our Terms of Service (https://docs.github.com/en/site-policy/github-terms/github-terms-of-service).

# %%
# print(result)
for output in result.get_outputs():
    output = str.replace(output.text, ". ", ".\n")
    print(f"{output}\n")
