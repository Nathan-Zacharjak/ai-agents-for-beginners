# %% [markdown]
# # ⏩ Sequential Agent Workflows with GitHub Models (Python)
#
# ## 📋 Advanced Sequential Processing Tutorial
#
# This notebook demonstrates **sequential workflow patterns** using the Microsoft Agent Framework. You'll learn how to build sophisticated multi-step processing pipelines where agents execute in a specific order, passing data and context between stages.
#
# ## 🎯 Learning Objectives
#
# ### 🔄 **Sequential Processing Patterns**
# - **Linear Workflow Design**: Create step-by-step processing pipelines
# - **Data Flow Management**: Pass information between sequential agents
# - **Stage-Gate Processing**: Implement checkpoints and validation stages
# - **Progress Tracking**: Monitor workflow execution and intermediate results
#
# ### 🏗️ **Enterprise Pipeline Architecture**
# - **Business Process Modeling**: Map real business processes to agent workflows
# - **Quality Assurance**: Multi-stage validation and review processes
# - **Document Processing**: Sequential document analysis and transformation
# - **Content Production**: Editorial workflows with review and approval stages
#
# ### 📊 **Advanced Workflow Features**
# - **Context Preservation**: Maintain state across workflow stages
# - **Error Propagation**: Handle failures in sequential processing
# - **Performance Optimization**: Efficient sequential execution patterns
# - **Audit Trails**: Complete tracking of sequential operations
#
# ## ⚙️ Prerequisites & Setup
#
# ### 📦 **Dependencies**
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **Configuration**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🏢 **Enterprise Sequential Workflow Use Cases**
#
# ### 📝 **Document Processing Pipeline**
# ```
# Raw Document → Content Extraction → Analysis → Validation → Final Output
# ```
#
# ### 🔍 **Quality Assurance Workflow**
# ```
# Initial Review → Technical Validation → Compliance Check → Final Approval
# ```
#
# ### 📰 **Content Production Pipeline**
# ```
# Research → Writing → Editing → Review → Publishing
# ```
#
# ### 💼 **Business Process Automation**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ## 🎨 **Sequential Workflow Design Principles**
#
# - **🔗 Linear Progression**: Each stage depends on the previous stage's output
# - **📋 State Management**: Preserve context and data across all stages
# - **🛡️ Error Handling**: Graceful failure management in any stage
# - **📊 Progress Monitoring**: Track completion and performance at each stage
# - **🔄 Stage Reusability**: Design reusable workflow components
#
# Let's build sophisticated sequential processing workflows! 🚀

# %%
! pip install agent-framework-core -U
# Out:
# Requirement already satisfied: agent-framework-core in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (1.0.0b260212)
# Requirement already satisfied: typing-extensions in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from agent-framework-core) (4.15.0)
# Requirement already satisfied: pydantic<3,>=2 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from agent-framework-core) (2.11.10)
# Requirement already satisfied: python-dotenv<2,>=1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from agent-framework-core) (1.2.1)
# Requirement already satisfied: opentelemetry-api>=1.39.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from agent-framework-core) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.39.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from agent-framework-core) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from agent-framework-core) (0.4.13)
# Requirement already satisfied: openai>=1.99.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from agent-framework-core) (2.20.0)
# Requirement already satisfied: azure-identity<2,>=1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from agent-framework-core) (1.25.2)
# Requirement already satisfied: azure-ai-projects>=2.0.0b3 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from agent-framework-core) (2.0.0b3)
# Requirement already satisfied: mcp<2,>=1.24.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp[ws]<2,>=1.24.0->agent-framework-core) (1.26.0)
# Requirement already satisfied: packaging>=24.1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from agent-framework-core) (26.0)
# Requirement already satisfied: azure-core>=1.31.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.38.1)
# Requirement already satisfied: cryptography>=2.5 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from azure-identity<2,>=1->agent-framework-core) (46.0.5)
# Requirement already satisfied: msal>=1.31.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.3.1)
# Requirement already satisfied: anyio>=4.5 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (4.12.1)
# Requirement already satisfied: httpx-sse>=0.4 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (4.26.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.0.22)
# Requirement already satisfied: sse-starlette>=1.6.1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (3.2.0)
# Requirement already satisfied: starlette>=0.27 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.40.0)
# Requirement already satisfied: websockets>=15.0.1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from mcp[ws]<2,>=1.24.0->agent-framework-core) (15.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from pydantic<3,>=2->agent-framework-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from pydantic<3,>=2->agent-framework-core) (2.33.2)
# Requirement already satisfied: idna>=2.8 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from anyio>=4.5->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (3.11)
# Requirement already satisfied: isodate>=0.6.1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from azure-ai-projects>=2.0.0b3->agent-framework-core) (0.7.2)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from azure-ai-projects>=2.0.0b3->agent-framework-core) (12.28.0)
# Requirement already satisfied: requests>=2.21.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.0.0)
# Requirement already satisfied: pycparser in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (3.0)
# Requirement already satisfied: certifi in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.36.2)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.30.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.6.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from openai>=1.99.0->agent-framework-core) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from openai>=1.99.0->agent-framework-core) (0.13.0)
# Requirement already satisfied: sniffio in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from openai>=1.99.0->agent-framework-core) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from openai>=1.99.0->agent-framework-core) (4.67.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from opentelemetry-api>=1.39.0->agent-framework-core) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.39.0->agent-framework-core) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from opentelemetry-sdk>=1.39.0->agent-framework-core) (0.60b1)
# Requirement already satisfied: click>=7.0 in /home/vscode/.pyenv/versions/venv/lib/python3.13/site-packages (from uvicorn>=0.31.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (8.3.1)

# %%
from agent_framework.openai import OpenAIChatClient
from agent_framework import Message, Content, Role, WorkflowBuilder,  WorkflowEvent,WorkflowViz

# %%
import os
import base64
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
chat_client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id="gpt-4o" )

# %%
SalesAgentName = "Sales-Agent"
SalesAgentInstructions = "You are my furniture sales consultant, you can find different furniture elements from the pictures and give me a purchase suggestion"

# %%
PriceAgentName = "Price-Agent"
PriceAgentInstructions = """You are a furniture pricing specialist and budget consultant. Your responsibilities include:
        1. Analyze furniture items and provide realistic price ranges based on quality, brand, and market standards
        2. Break down pricing by individual furniture pieces
        3. Provide budget-friendly alternatives and premium options
        4. Consider different price tiers (budget, mid-range, premium)
        5. Include estimated total costs for room setups
        6. Suggest where to find the best deals and shopping recommendations
        7. Factor in additional costs like delivery, assembly, and accessories
        8. Provide seasonal pricing insights and best times to buy
        Always format your response with clear price breakdowns and explanations for the pricing rationale."""

# %%
QuoteAgentName = "Quote-Agent"
QuoteAgentInstructions = """You are a assistant that create a quote for furniture purchase.
        1. Create a well-structured quote document that includes:
        2. A title page with the document title, date, and client name
        3. An introduction summarizing the purpose of the document
        4. A summary section with total estimated costs and recommendations
        5. Use clear headings, bullet points, and tables for easy readability
        6. All quotes are presented in markdown form"""

# %%
sales_agent   = chat_client.as_agent(
        instructions=(
           SalesAgentInstructions
        ),
        name=SalesAgentName,
    )

price_agent = chat_client.as_agent(
        instructions=(
            PriceAgentInstructions
        ),
        name=PriceAgentName,
    )

quote_agent = chat_client.as_agent(
        instructions=(
            QuoteAgentInstructions
        ),
        name=QuoteAgentName,
    )

# %%
workflow = WorkflowBuilder(start_executor=sales_agent).add_edge(sales_agent, price_agent).add_edge(price_agent, quote_agent).build()

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
svg_file = viz.export(format="svg")
print(f"SVG file saved to: {svg_file}")
# Out:
# Generating workflow visualization...
# Mermaid string:
# =======
# flowchart TD
#   Sales_Agent["Sales-Agent (Start)"];
#   Price_Agent["Price-Agent"];
#   Quote_Agent["Quote-Agent"];
#   Sales_Agent --> Price_Agent;
#   Price_Agent --> Quote_Agent;
# =======
# DiGraph string:
# =======
# digraph Workflow {
#   rankdir=TD;
#   node [shape=box, style=filled, fillcolor=lightblue];
#   edge [color=black, arrowhead=vee];
#
#   "Sales-Agent" [fillcolor=lightgreen, label="Sales-Agent\n(Start)"];
#   "Price-Agent" [label="Price-Agent"];
#   "Quote-Agent" [label="Quote-Agent"];
#   "Sales-Agent" -> "Price-Agent";
#   "Price-Agent" -> "Quote-Agent";
# }
# =======
# SVG file saved to: /tmp/tmptc58s31h.svg

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
# Display the exported workflow SVG inline in the notebook

from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")
# Out:
# Attempting to display SVG file at: /tmp/tmptc58s31h.svg

# %%
image_path = "../imgs/home.png"
with open(image_path, "rb") as image_file:
    image_b64 = base64.b64encode(image_file.read()).decode()
image_uri = f"data:image/png;base64,{image_b64}"

# %%
message = Message(
        role="user",
        contents=[
            Content(text="Please find the relevant furniture according to the image and give the corresponding price for each piece of furniture", type="text"),
            Content(uri=image_uri, type="uri", media_type="image/png")
        ]
)

# %%
result=''
result = await workflow.run(message)
# async for event in workflow.run(message, stream=True):
#     if isinstance(event, DatabaseEvent):
#         print(f"{event}")
#     if isinstance(event, WorkflowEvent):
#         result += str(event.data)

# %%
# print(result)
for output in result.get_outputs():
    output = str.replace(output.text, ". ", ".\n")
    print(f"{output}\n")
# Out:
# Here is a breakdown of the furniture in the image along with general purchase suggestions:
#
# ### 1.
# **TV Console/Media Unit**
#    - Features: Wooden design with drawers and open shelving.
# Compact and modern style.
#    - Price Estimate: $150 - $400 depending on material and brand.
#
# ### 2.
# **Coffee Table**
#    - Features: Round shape with a light-toned top and tapered legs that match the room's minimalistic aesthetic.
#    - Price Estimate: $80 - $200.
#
# ### 3.
# **Sofa**
#    - Features: White or cream modern design with decorative pillows in shades of blue.
# Seats 3-4 people.
#    - Price Estimate: $300 - $700 depending on upholstery material and quality.
#
# ### 4.
# **Armchair**
#    - Features: Deep blue with an angled modern look, perfect for accent seating.
#    - Price Estimate: $150 - $400.
#
# ### 5.
# **Side Tables**
#    - Features: Slim and minimalist side tables on both sides.
# One table is metal or glass-based.
#    - Price Estimate: $50 - $150 each.
#
# ### 6.
# **Lighting Fixtures**
#    - Chandelier: Features an industrial-style black fixture with round glass globes.
#         - Price Estimate: $100 - $300.
#    - Floor Lamp: Slim metallic design.
#         - Price Estimate: $50 - $150.
#
# ### 7.
# **Curtains**
#    - Features: Neutral grey color, blending well with the space.
#    - Price Estimate: $50 - $200 depending on size and fabric.
#
# ---
#
# The exact pricing may vary based on brand, materials, and retailer.
# For accurate prices, you can check online furniture stores like Wayfair, IKEA, West Elm, or Ashley Furniture.
# Let me know if you'd like retailer links or specific suggestions!
#
# ### Estimated Furniture Costs:
#
# Here is the pricing breakdown for the furniture and accessories in the room shown in the image:
#
# ---
#
# ### **1.
# TV Console / Media Unit**
# - **Features**: Low-profile wooden design with drawers and open shelving.
# - **Price Range**:
#   - **Budget**: $150 - $250 (e.g., IKEA, Target)
#   - **Mid-Range**: $300 - $600 (e.g., CB2, Wayfair)
#   - **Premium**: $800+ (e.g., West Elm, Pottery Barn)
#
# ---
#
# ### **2.
# Coffee Table**
# - **Features**: Oval-shaped top with a light wood or marble finish and tapered legs.
# - **Price Range**:
#   - **Budget**: $80 - $150 (e.g., Walmart, Amazon Basics)
#   - **Mid-Range**: $200 - $400 (e.g., Article, AllModern)
#   - **Premium**: $500+ (e.g., Restoration Hardware, West Elm)
#
# ---
#
# ### **3.
# Sofa**
# - **Features**: Cream/white fabric, clean-lined modern design, with accent cushions in soft blue tones.
# - **Price Range**:
#   - **Budget**: $300 - $500 (e.g., IKEA, Wayfair)
#   - **Mid-Range**: $700 - $1,500 (e.g., Joybird, West Elm)
#   - **Premium**: $2,000+ (e.g., Crate & Barrel, Pottery Barn)
#
# ---
#
# ### **4.
# Accent Armchair**
# - **Features**: Dark navy fabric with contemporary design and tapered legs.
# - **Price Range**:
#   - **Budget**: $100 - $200 (e.g., Walmart, AllModern)
#   - **Mid-Range**: $300 - $500 (e.g., Article, CB2)
#   - **Premium**: $600+ (e.g., West Elm)
#
# ---
#
# ### **5.
# Side Tables**
# - **Features**: Minimalist, mixed materials (e.g., metal and glass or wood).
# One near the sofa and another near the chair.
# - **Price per Table**:
#   - **Budget**: $50 - $100 (e.g., Amazon Basics, IKEA)
#   - **Mid-Range**: $150 - $300 (e.g., CB2, Wayfair)
#   - **Premium**: $400+ (e.g., Anthropologie)
#
# ---
#
# ### **6.
# Lighting Fixtures**
#    #### a.
# **Chandelier**:
#    - **Features**: Black metal with a modern, industrial style and globe lightbulbs.
#    - **Price Range**:
#      - **Budget**: $100 - $200 (e.g., Home Depot, Wayfair)
#      - **Mid-Range**: $250 - $500 (e.g., Lumens, West Elm)
#      - **Premium**: $800+ (e.g., RH, Design Within Reach)
#
#    #### b.
# **Floor/Table Lamp**:
#    - **Features**: Metallic slim standing lamp with attached pendants.
#    - **Price Range**:
#      - **Budget**: $50 - $120 (e.g., IKEA, Target)
#      - **Mid-Range**: $150 - $300 (e.g., AllModern)
#      - **Premium**: $400+ (e.g., Restoration Hardware)
#
# ---
#
# ### **7.
# Curtains**
# - **Features**: Simple and neutral-colored curtains with floor-length drapery.
# - **Price Range**:
#   - **Budget**: $40 - $120 (e.g., Amazon, IKEA)
#   - **Mid-Range**: $150 - $300 (e.g., Wayfair, QVC)
#   - **Premium**: $400+ (e.g., Pottery Barn)
#
# ---
#
# ### **8.
# Wall Art**
# - **Features**: Framed modern art depicting a deer.
# - **Price Range**:
#   - **Budget**: $20 - $50 (e.g., Etsy, poster shops)
#   - **Mid-Range**: $80 - $150 (e.g., Minted, Society6)
#   - **Premium**: $200+ (e.g., Fine Art America, custom work)
#
# ---
#
# ### **Estimated Room Setup Costs (Total)**
# - **Budget Range**: $770 - $1,590
# - **Mid-Range**: $2,130 - $3,950
# - **Premium**: $5,000+
#
# This budget estimate doesn’t include taxes, shipping, or assembly costs, which can add 10-20% to the total price depending on the retailer.
# Let me know if you want recommendations for specific stores or cheaper alternatives!
#
# ### Furniture Quote Document
#
# # **Living Room Furniture Quote**
# **Date:** [Insert Date]
# **Client Name:** [Insert Client Name]
#
# ---
#
# ## **Introduction**
# This document outlines a detailed quote for the furniture items observed in the provided living room image.
# The following items have been analyzed and priced based on industry averages and online market research.
# These prices are estimates only and may vary depending on final selections and vendor availability.
#
# ---
#
# ## **Furniture Quote Summary**
#
# | **No.** | **Item**               | **Description**                                                               | **Estimated Price Range** |
# |---------|------------------------|-------------------------------------------------------------------------------|---------------------------|
# | 1       | **TV Console**         | Wooden, modern design, storage drawers                                         | $150 - $600              |
# | 2       | **Coffee Table**       | Oval-shaped top, light wood/marble finish, modern look                         | $80 - $500               |
# | 3       | **Sofa**               | White fabric, contemporary style, 3-4 seat capacity, blue accent cushions      | $300 - $2,000+           |
# | 4       | **Accent Armchair**    | Navy/dark blue, minimalist design                                              | $100 - $600+             |
# | 5       | **Side Tables**        | Metal/glass combination, modern and sleek (2 pieces)                           | $50 - $400 each          |
# | 6a      | **Chandelier**         | Black frame with round globe bulbs                                             | $100 - $800+             |
# | 6b      | **Floor/Table Lamp**   | Slim metallic structure with pendant features                                  | $50 - $400+              |
# | 7       | **Curtains**           | Neutral grey, simple, floor-length design                                      | $40 - $400+              |
# | 8       | **Wall Art**           | Framed modern piece (deer illustration)                                        | $20 - $200+              |
#
# ---
#
# ## **Recommendations**
# - **Budget Options**: Consider shopping at IKEA, Wayfair, and Amazon for economical options.
#
# - **Mid-Range Options**: Platforms like CB2, AllModern, and Article offer high-quality furnishings at reasonable prices.
#
# - **Premium Options**: Explore brands like West Elm, Restoration Hardware, and Pottery Barn for luxurious finishes.
#
# > **Total Estimated Cost (Budget to Premium)**: $770 - $5,000+ (excluding taxes and shipping)
#
# Let us know if you'd like assistance finalizing the selections or finding a furniture retailer.
# Thank you!
